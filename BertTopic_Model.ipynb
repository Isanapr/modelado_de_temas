# %% [markdown]
# #BERTopic  Model
#
# Bertopic es un algoritmo de modelado de temas, emplea embeddings y transformaciones c-TF-IDF para crear clusters que permiten interpretar temas a partir de palabras similares.

# %%
# !pip install bertopic &> /dev/null

# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# %%
from pandas._libs.tslibs import timestamps
input_file="economics_TW.csv"
#--------------------------------------------
df=pd.read_csv(input_file)
docs=df["Filtered"]
timestamps=df["Date"]
print(f"@economics with {len(docs)} tweets")
df.head()
# Out:
# @economics with 2445 tweets
#    Unnamed: 0                                              Tweet  \
# 0           0  Waste-to-hydrogen technology firm Concord Blue...
# 1           1  Bitcoin is struggling to gain traction in El S...
# 2           2  The Star Ferry, an icon of Hong Kong and argua...
# 3           3  Food and energy price surges worsened by the U...
# 4           4  President Joe Biden is considering forgiving a...
#
#                                             Filtered                 Date
# 0  Waste- to- hydrogen technology firm Concord Bl...  2022-04-30 18:29:21
# 1  Bitcoin is struggling to gain traction in El S...  2022-04-30 18:08:05
# 2  The Star Ferry, an icon of Hong Kong and argua...  2022-04-30 17:35:35
# 3  Food and energy price surges worsened by the U...  2022-04-30 17:08:03
# 4  President Joe Biden is considering forgiving a...  2022-04-30 16:28:48

# %% [markdown]
# # Static Bert
# Modelado de temas sin consideración temporal. <br>
# Esto permite crear gráficos con representación de similitud entre temas.

# %%
#Elimina las palabras de tope
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english") 
#Creates the model
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.get_topic(0)  # Temas mas frecuentes
# Out:
# [('russia', 0.03221385974484918),
#  ('ukraine', 0.025378324073781235),
#  ('russian', 0.0223795068258739),
#  ('gas', 0.020192699317231874),
#  ('war', 0.01864178697659027),
#  ('invasion', 0.01639989489167486),
#  ('invasion ukraine', 0.015178754760772847),
#  ('sanctions', 0.013107079516856501),
#  ('war ukraine', 0.012433059347707724),
#  ('germany', 0.012359825289497197)]

# %%
topic_model.visualize_topics() #Visualiza similaridad entre temas
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="272be435-3141-4edc-9621-6ef59c401449" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("272be435-3141-4edc-9621-6ef59c401449")) {                    Plotly.newPlot(                        "272be435-3141-4edc-9621-6ef59c401449",                        [{"customdata":[[1,"fed | recession | federal | federal reserve | rates",138],[2,"inflation | consumer | americans | high | pressures",104],[3,"energy | costs | electricity | prices | energy costs",77],[4,"japan | yen | bank japan | bank | weakening",67],[5,"uk | brexit | living | rishi sunak | rishi",62],[6,"central | bitcoin | digital | crypto | bankers",51],[7,"korea | singapore | south korea | bank korea | south",49],[8,"ecb | rates | council member | governing council | council",48],[9,"unemployment | labor | labor market | workers | market",48],[10,"mortgage | home | mortgage rates | property | housing",47],[11,"covid | china | lockdowns | covid lockdowns | covid zero",42],[12,"sri | sri lanka | lanka | crisis | debt",41],[13,"zealand | new zealand | australia | zealand central | new",37],[14,"africa | south africa | south | killed | private",31],[15,"chile | peru | president | inflation | soaring inflation",31],[16,"pandemic | return | employees | study | desks",30],[17,"travel | gasoline | buying | gasoline just | fuel",29],[18,"container | shipping | ports | port | ship",28],[19,"canada | bank canada | justin | trudeau | justin trudeau",28],[20,"china central | china | central bank | central | support",28],[21,"yellen | janet | janet yellen | secretary janet | treasury secretary",27],[22,"pakistan | imf | pakistan new | imran khan | khan",24],[23,"war ukraine | ukraine | war | russia war | inflation",24],[24,"indonesia | oil | exports | cooking oil | cooking",23],[25,"gender | women | pay gap | gender pay | gap",23],[26,"czech | central bank | czech central | riksbank | rate",22],[27,"outbreak | covid | cases | shanghai | hong",22],[28,"latest news | news russia | ukraine latest | news | latest",21],[29,"india | central bank | india central | central | borrowing",21],[30,"covid19 | africa | positive | tested positive | incidence",20],[31,"fertilizer | farmers | rice | staple | fertilizer prices",20],[32,"china | virus | supply chains | chains | lockdowns",19],[33,"brazil | rose forecast | fintechs | brazil consumer | brazil central",18],[34,"turkey | lira | currency | turkish | reserves turkey",17],[35,"housing | red hot | red | hot | canada",17],[36,"gulf | saudi | north african | arabia | saudi arabia",17],[37,"mexico | lopez obrador | lopez | obrador | manuel",16],[38,"xi jinping | jinping | xi | president xi | president",16],[39,"oil | drilling | crude | biden | biden effort",16],[40,"macron | pen | le | le pen | french",16],[41,"border | mexican | blockade | abbott | crossing",15],[42,"food | food prices | surging fastest | hunger crisis | hunger",15],[43,"trade | india | boris johnson | boris | johnson",15],[44,"student | student loan | loan | borrowers | loan payments",14],[45,"bloomberg | charts | charting global | pret index | 12 global",14],[46,"updates | latest updates | updates russian | russian invasion | latest",14],[47,"kenya | kenyan | shortages | dollars | tax",13],[48,"customers | decadent snack | breakfast | decadent | carl",13],[49,"food | staples | harvests | global food | food prices",13],[50,"tax | highest earning | earning | according | continues",13],[51,"world economy | lookout world | lookout | world | world good",12],[52,"india | russia | local currencies | bilateral | proposal",12],[53,"gdp | gdp day | day | biden | economic",11],[54,"biden | solar | biden administration | challenges decides | economic challenges",11]],"hovertemplate":"<b>Topic %{custom ...

# %%
topic_model.visualize_distribution(probs[200], min_probability=0.015) #Muestra la distribución de probabilidades
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6dd610dd-1f1d-47b7-aba6-3452bcc1a739" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dd610dd-1f1d-47b7-aba6-3452bcc1a739")) {                    Plotly.newPlot(                        "6dd610dd-1f1d-47b7-aba6-3452bcc1a739",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.04567058527452939,0.03710912760186585,0.03144747553529108,0.016680724449178803,0.03376525451781854,0.49564974339849827],"y":["<b>Topic 11</b>: covid_china_lockdowns_c...","<b>Topic 20</b>: china central_china_cen...","<b>Topic 27</b>: outbreak_covid_cases_sh...","<b>Topic 30</b>: covid19_africa_positive...","<b>Topic 32</b>: china_virus_supply chai...","<b>Topic 38</b>: xi jinping_jinping_xi_p..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"] ...

# %% [markdown]
# # Dynamic Bert
# Modelado de temas con consideración temporal.

# %%
topics_over_time = topic_model.topics_over_time(docs=docs, 
                                                topics=topics, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# 20it [00:03,  6.53it/s]

# %%
#Frecuencia de temas en el tiempo
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="113e7a60-8f19-458a-8c0b-e5ee06187c26" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("113e7a60-8f19-458a-8c0b-e5ee06187c26")) {                    Plotly.newPlot(                        "113e7a60-8f19-458a-8c0b-e5ee06187c26",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: russia, ukraine, invasion, invasion ukraine, germany","<b>Topic 0</b><br>Words: russian, russia, ukraine, gas, invasion","<b>Topic 0</b><br>Words: russia, ukraine, russia invasion, invasion, invasion ukraine","<b>Topic 0</b><br>Words: russia, ukraine, russian, sanctions, sustainable","<b>Topic 0</b><br>Words: russia, ukraine, russian, sanctions, invasion","<b>Topic 0</b><br>Words: russia, russian, ukraine, eu, coal","<b>Topic 0</b><br>Words: russia, ukraine, russian, sanctions, war","<b>Topic 0</b><br>Words: ratings, default, russia, country, credit ratings","<b>Topic 0</b><br>Words: russia, russian, putin invasion, ukraine, says","<b>Topic 0</b><br>Words: russia, gas, russian, ukraine, war","<b>Topic 0</b><br>Words: russia, ukraine, gas, russian, invasion","<b>Topic 0</b><br>Words: embargo, grain, russian gas, gas, qampa","<b>Topic 0</b><br>Words: russia, gas, russian, sanctions, ukraine","<b>Topic 0</b><br>Words: russia, ukraine, war, russian, gas","<b>Topic 0</b><br>Words: russia, ukraine, russian, billion, ukraine russia","<b>Topic 0</b><br>Words: war, russia, ukraine, billion euros, euros","<b>Topic 0</b><br>Words: ukraine, war, russia, war ukraine, russian","<b>Topic 0</b><br>Words: russia, gas, ukraine, war, russian","<b>Topic 0</b><br>Words: russia, gas, germany, ukraine, russian","<b>Topic 0</b><br>Words: russia, gas, russian, ukraine, europe"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_russia_ukraine_russian_gas","x":["2022-03-28T17:10:27.920000","2022-03-30T09:35:35","2022-04-01T01:13:09","2022-04-02T16:50:43","2022-04-04T08:28:17","2022-04-06T00:05:51","2022-04-07T15:43:25","2022-04-09T07:20:59","2022-04-10T22:58:33","2022-04-12T14:36:07","2022-04-14T06:13:41","2022-04-15T21:51:15","2022-04-17T13:28:49","2022-04-19T05:06:23","2022-04-20T20:43:57","2022-04-22T12:21:31","2022-04-24T03:59:05","2022-04-25T19:36:39","2022-04-27T11:14:13","2022-04-29T02:51:47"],"y":[15,20,19,10,18,17,22,4,9,12,16,4,7,18,11,13,16,10,23,24],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: fed, yield curve, curve, yield, lisa cook","<b>Topic 1</b><br>Words: fed, inversion, yield curve, curve, fed president","<b>Topic 1</b><br>Words: recession, fed, chief economist, increases, recent","<b>Topic 1</b><br>Words: fed, yield curve, curve, federal reserve, yield","<b>Topic 1</b><br>Words: fed, recession, rates, says, federal reserve","<b>Topic 1</b><br>Words: fed, balance sheet, balance, sheet, policy","<b>Topic 1</b><br>Words: federal reserve, federal, fed, reserve, recession","<b>Topic 1</b><br>Words: federal reserve, federal, fed, reserve, says fed","<b>Topic 1</b><br>Words: fed, 10year, federal, president, policy","<b>Topic 1</b><br>Words: fed, raise rates, raise, fed president, federal reserve","<b>Topic 1</b><br>Words: fed, raise, fed president, hawkish, raise rates","<b>Topic 1</b><br>Words: fed, recession, bank pre, landing amp, accurate","<b>Topic 1</b><br>Words: fed, recession, tightening cause, fed hard, recession 35","<b>Topic 1</b><br>Words: fed, 75 basis, 75, betting, rates","<b>Topic 1</b><br>Words: fed, powell, fed chair, jerome, jerome powell","<b>Topic 1</b><br>Words: fed, point, bond market, rates, hawkish","<b>Topic 1</b><br>Words: fed, market, worries emerging, preview shrinking, higher bond","<b>Topic 1</b><br>Words: fed, person, hold person, conference pandemic, press conference","<b>Topic ...

# %% [markdown]
# # Biliografía
# https://github.com/MaartenGr/BERTopic  <br>
# https://maartengr.github.io/BERTopic/api/bertopic.html
